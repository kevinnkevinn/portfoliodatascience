# %% [markdown]
# **Child Sexual Abuse** is described as sexual contact between an adult, adolescent, or older kid and a child. Sexual abuse occurs when an adult engages in sexual behavior with a youngster. If another kid or adolescent participates in sexual activity with a youngster, there is a gray area in which some sexual conduct is exploratory and not abusive.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://github.com/kevinnkevinn/portfoliodatascience/raw/main/Data%20Source/CSA-Data.csv", sep=",")
data.head()
# Out:
#   "Children are safe among family members such as grandparents, uncles, aunts, cousins"  \
# 0                                              Agree
# 1                                              Agree
# 2                                           Disagree
# 3                                              Agree
# 4                                              Agree
#
#   "Children are mainly abused by strangers in our society"  \
# 0                                              Agree
# 1                                              Agree
# 2                                           Disagree
# 3                                              Agree
# 4                                           Disagree
#
#   Male children dont need sexual abuse prevention knowledge  \
# 0                                           Disagree
# 1                                           Disagree
# 2                                           Disagree
# 3                                           Disagree
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3002 entries, 0 to 3001
# Data columns (total 9 columns):
#  #   Column                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                  --------------  -----
#  0   "Children are safe among family members such as grandparents, uncles, aunts, cousins"                   3002 non-null   object
#  1   "Children are mainly abused by strangers in our society"                                                3002 non-null   object
#  2   Male children dont need sexual abuse prevention knowledge                                               3002 non-null   object
#  3   "Teaching sexual abuse prevention in school is not necessary. It will make children curious about sex"  3002 non-null   object
# ...

# %%
data.describe()
# Out:
#        "Children are safe among family members such as grandparents, uncles, aunts, cousins"  \
# count                                                3002
# unique                                                  2
# top                                              Disagree
# freq                                                 1632
#
#        "Children are mainly abused by strangers in our society"  \
# count                                                3002
# unique                                                  2
# top                                              Disagree
# freq                                                 1700
#
#        Male children dont need sexual abuse prevention knowledge  \
# count                                                3002
# unique                                                  2
# top                                              Disagree
# freq                                                 1908
#
# ...

# %%
q1 = '"Children are safe among family members such as grandparents, uncles, aunts, cousins"'
q2 = '"Children are mainly abused by strangers in our society"'
q3 = 'Male children dont need sexual abuse prevention knowledge'
q4 = '"Teaching sexual abuse prevention in school is not necessary. It will make children curious about sex"'
q5 = 'Do you know what child grooming is?'
q6 = 'Do you know what signs to look for to identify if your child has been abused?'
q7 = 'Do you think children need post abuse counseling for recovering?'
q8 = 'Do you think you should take legal action against the abuser of your child?'
q9 = 'Knowledge Level'

# %%
data.isnull().any()
# Out:
# "Children are safe among family members such as grandparents, uncles, aunts, cousins"                     False
# "Children are mainly abused by strangers in our society"                                                  False
# Male children dont need sexual abuse prevention knowledge                                                 False
# "Teaching sexual abuse prevention in school is not necessary. It will make children curious about sex"    False
# Do you know what child grooming is?                                                                       False
# Do you know what signs to look for to identify if your child has been abused?                             False
# Do you think children need post abuse counseling for recovering?                                          False
# Do you think you should take legal action against the abuser of your child?                               False
# ...

# %%
sns.countplot(data[q1])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='"Children are safe among family members such as grandparents, uncles, aunts, cousins"', ylabel='count'>

# %%
sns.countplot(data[q2])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='"Children are mainly abused by strangers in our society"', ylabel='count'>

# %%
sns.countplot(data[q3])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Male children dont need sexual abuse prevention knowledge', ylabel='count'>

# %%
sns.countplot(data[q4])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='"Teaching sexual abuse prevention in school is not necessary. It will make children curious about sex"', ylabel='count'>

# %%
sns.countplot(data[q5])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Do you know what child grooming is?', ylabel='count'>

# %%
sns.countplot(data[q6])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Do you know what signs to look for to identify if your child has been abused?', ylabel='count'>

# %%
sns.countplot(data[q7])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Do you think children need post abuse counseling for recovering?', ylabel='count'>

# %%
sns.countplot(data[q8])
# Out:
# C:\Users\Kevin Kiding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Do you think you should take legal action against the abuser of your child?', ylabel='count'>

# %%
data[q1].replace('Agree',1,inplace=True)
data[q1].replace('Disagree',0,inplace=True)

data[q2].replace('Agree',1,inplace=True)
data[q2].replace('Disagree',0,inplace=True)

data[q3].replace('Agree',1,inplace=True)
data[q3].replace('Disagree',0,inplace=True)

data[q4].replace('Agree',1,inplace=True)
data[q4].replace('Disagree',0,inplace=True)

# %%
data[q5].replace('Yes',1,inplace=True)
data[q5].replace('No',0,inplace=True)

data[q6].replace('Yes',1,inplace=True)
data[q6].replace('No',0,inplace=True)

data[q7].replace('Yes',1,inplace=True)
data[q7].replace('No',0,inplace=True)

data[q8].replace('Yes',1,inplace=True)
data[q8].replace('No',0,inplace=True)

# %%
data.tail(5)
# Out:
#       "Children are safe among family members such as grandparents, uncles, aunts, cousins"  \
# 2997                                                  1
# 2998                                                  1
# 2999                                                  1
# 3000                                                  0
# 3001                                                  0
#
#       "Children are mainly abused by strangers in our society"  \
# 2997                                                  1
# 2998                                                  1
# 2999                                                  1
# 3000                                                  1
# 3001                                                  0
#
#       Male children dont need sexual abuse prevention knowledge  \
# 2997                                                  0
# 2998                                                  0
# 2999                                                  1
# ...

# %% [markdown]
# ## Extracting Feature columns and Target Columns

# %%
X = data.iloc[:, 0:8]
y = data[q9]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, stratify = y, random_state= 0)

# %%
print("Numbers of Train Dataset:", len(X_train))
print("Numbers of Test Dataset:", len(X_test))
# Out:
# Numbers of Train Dataset: 2251
# Numbers of Test Dataset: 751

# %% [markdown]
# ## Machine Leanring

# %% [markdown]
# ### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred_lr = logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

labels = ['Beginner','Intermediate']
sns.heatmap(confusion_matrix(y_test, y_pred_lr), xticklabels = labels, yticklabels = labels, annot = True, fmt='d', cmap = "BuPu")
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#     Beginner       0.92      0.81      0.86       428
# Intermediate       0.78      0.90      0.84       323
#
#     accuracy                           0.85       751
#    macro avg       0.85      0.86      0.85       751
# weighted avg       0.86      0.85      0.85       751

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)

# %%
print(f'Accuracy: {accuracy_score(y_test, y_pred_nb)}\n')
sns.heatmap(confusion_matrix(y_test, y_pred_nb), xticklabels = labels, yticklabels = labels, annot = True, fmt='d', cmap = "YlGnBu")
print(f'Classification Report: \n {classification_report(y_test, y_pred_nb)}')
# Out:
# Accuracy: 0.7643142476697736
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Beginner       0.78      0.82      0.80       428
# Intermediate       0.74      0.69      0.72       323
#
#     accuracy                           0.76       751
#    macro avg       0.76      0.76      0.76       751
# weighted avg       0.76      0.76      0.76       751

# %% [markdown]
# ## Support Vector Classifier (SVC)

# %% [markdown]
# **Support Vector Classifier** is a supervised machine learning technique that is commonly employed for classification applications. The SVC algorithm operates by mapping data points to a high-dimensional space and then locating the best hyperplane that separates the data into two groups.

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, y_train)
y_pred_svc = svc.predict(X_test)

# %%
print(f'Accuracy: {accuracy_score(y_test, y_pred_svc)}\n')
sns.heatmap(confusion_matrix(y_test, y_pred_svc), xticklabels = labels, yticklabels = labels, annot = True, fmt='d', cmap = "Greens")
print(f'Classification Report: \n {classification_report(y_test, y_pred_svc)}')
# Out:
# Accuracy: 0.9081225033288948
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Beginner       0.92      0.92      0.92       428
# Intermediate       0.90      0.89      0.89       323
#
#     accuracy                           0.91       751
#    macro avg       0.91      0.91      0.91       751
# weighted avg       0.91      0.91      0.91       751

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# **Decision Tree** is a tree structure that looks like a flowchart. Each internal node is a feature or attribute, each branch is a decision rule, and each leaf node is the result. The node at the very top of a decision tree is called the "root node." It learns to divide based on the value of an attribute. It divides the tree into sections in a way called "recursively." This structure, which looks like a flowchart, helps you decide what to do. It looks like a flowchart diagram, which is a good way to show how people think. Because of this, decision trees are easy to read and understand.

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# %%
print(f'Accuracy: {accuracy_score(y_test, y_pred_dt)}\n')
sns.heatmap(confusion_matrix(y_test, y_pred_dt), xticklabels = labels, yticklabels = labels, annot = True, fmt='d', cmap ="OrRd")
print(f'Classification Report: \n {classification_report(y_test,y_pred_dt)}')
# Out:
# Accuracy: 0.9041278295605859
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Beginner       0.92      0.91      0.92       428
# Intermediate       0.88      0.89      0.89       323
#
#     accuracy                           0.90       751
#    macro avg       0.90      0.90      0.90       751
# weighted avg       0.90      0.90      0.90       751

# %% [markdown]
# ## Random Forest

# %% [markdown]
# **Random Forest** is an algorithm for supervised machine learning that is based on learning in groups. Ensemble learning is a way to learn in which different types of algorithms or the same algorithm is used more than once to make a stronger prediction model. The random forest algorithm combines several algorithms of the same type, called **decision trees.** This makes a forest of trees, which is why the algorithm is called **random forest.** When it comes to data analysis, the random forest approach is versatile enough to be utilized for both regression and classification.

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
print(f'Accuracy: {accuracy_score(y_test, y_pred_rf)}\n')
sns.heatmap(confusion_matrix(y_test, y_pred_rf), xticklabels = labels, yticklabels = labels, annot = True, fmt='d', cmap = "GnBu")
print(f'Classification Report: \n {classification_report(y_test, y_pred_rf)}')
# Out:
# Accuracy: 0.9094540612516645
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Beginner       0.92      0.92      0.92       428
# Intermediate       0.90      0.89      0.89       323
#
#     accuracy                           0.91       751
#    macro avg       0.91      0.91      0.91       751
# weighted avg       0.91      0.91      0.91       751

# %% [markdown]
# ## ML Models performance Visualization

# %%
acc_dict = {'LR':accuracy_score(y_test,y_pred_lr),
            'MNB':accuracy_score(y_test,y_pred_nb),
            'SVM':accuracy_score(y_test,y_pred_svc),
            'RF':accuracy_score(y_test,y_pred_rf),
            'DT':accuracy_score(y_test,y_pred_dt)}

# %%
algorithms = list(acc_dict.keys())
acc_score = list(acc_dict.values())

# %%
plt.figure(figsize=(10,6))
plt.bar(algorithms,
        acc_score,
        color = ['yellow', 'orange', 'red', 'violet', 'blue'],
        width = 0.35)
plt.xlabel("Name of Algorithms")
plt.ylabel("Accuracy Score")
plt.title(label = "Evaluation of accuracy score", fontsize = 18)
plt.show()

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# The definition of deep learning can be interpreted as a technique in machine learning that enables a computer system or machine to function like a natural human, specifically by studying situations with specific learning or programming.
#
# Additionally, the development of technology that is dependent on artificial intelligence or AI is made significantly easier through the use of deep learning (AI). During the process of deep learning, a computer will analyze a variety of models and categorize their respective duties depending on the data that it has acquired. It's possible for the data to be in the form of photos, text, or even sound. In point of fact, when dealing with enormous amounts of data, an even higher degree of precision is achieved.

# %%
from tensorflow.keras.utils import to_categorical
from keras.layers import Input,Dense
from keras import Model

# %%
y = data['Knowledge Level'].map({'Beginner':0,
                               'Intermediate':1})
y = to_categorical(y)

# %% [markdown]
# The map() function returns a map object (an iterator) containing the results of applying the given function to each item of an iterable.

# %%
input = Input(shape=8)
x = Dense(32, activation='relu')(input)
output = Dense(2, activation='softmax')(x)

model = Model(inputs = input, outputs = output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  dense (Dense)               (None, 32)                288
#
#  dense_1 (Dense)             (None, 2)                 66
#
# ...
# Total params: 354
# Trainable params: 354
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer ='adam', loss='binary_crossentropy', metrics = ['acc'])
history = model.fit(X, y, validation_split = 0.1,epochs = 45)
# Out:
# Epoch 1/45
# 85/85 [==============================] - 2s 8ms/step - loss: 0.6606 - acc: 0.6175 - val_loss: 0.6111 - val_acc: 0.7043
# Epoch 2/45
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5436 - acc: 0.7660 - val_loss: 0.5110 - val_acc: 0.8272
# Epoch 3/45
# 85/85 [==============================] - 0s 4ms/step - loss: 0.4560 - acc: 0.8467 - val_loss: 0.4436 - val_acc: 0.8804
# Epoch 4/45
# 85/85 [==============================] - 0s 4ms/step - loss: 0.4096 - acc: 0.8412 - val_loss: 0.4100 - val_acc: 0.8837
# Epoch 5/45
# 85/85 [==============================] - 0s 4ms/step - loss: 0.3875 - acc: 0.8515 - val_loss: 0.3892 - val_acc: 0.8837
# Epoch 6/45
# 85/85 [==============================] - 0s 4ms/step - loss: 0.3718 - acc: 0.8534 - val_loss: 0.3652 - val_acc: 0.8804
# Epoch 7/45
# 85/85 [==============================] - 0s 4ms/step - loss: 0.3575 - acc: 0.8556 - val_loss: 0.3491 - val_acc: 0.8837
# Epoch 8/45
# ...

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy', fontsize = 18)
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', fontsize = 18)
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Find and Save the best model

# %%
import pickle
pickle.dump(rf, open('child_sexual_abuse.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('child_sexual_abuse.pkl', 'rb'))
